# %%
import pandas as pd

# %%
df = pd.read_csv('gifts.csv')
df
# Out:
#        GiftId   Latitude   Longitude     Weight
# 0           1  16.345769    6.303545   1.000000
# 1           2  12.494749   28.626396  15.524480
# 2           3  27.794615   60.032495   8.058499
# 3           4  44.426992  110.114216   1.000000
# 4           5 -69.854088   87.946878  25.088892
# ...       ...        ...         ...        ...
# 99995   99996 -86.087115  -19.991474  10.927676
# 99996   99997  40.259124 -110.689749   9.347134
# 99997   99998  42.393016    0.011825   1.000000
# 99998   99999 -75.919193  -10.193532   1.000000
# 99999  100000  11.106159   40.230236   1.000000
#
# [100000 rows x 4 columns]

# %%
sorted_weight = df.sort_values(by=['Weight'],ascending=False)
sorted_weight
# Out:
#        GiftId   Latitude   Longitude  Weight
# 55047   55048  23.397175    4.031402    50.0
# 2719     2720  46.876776  106.222900    50.0
# 18504   18505  49.968062 -117.730307    50.0
# 18486   18487 -83.954576 -109.983391    50.0
# 55775   55776  48.445299  -66.885909    50.0
# ...       ...        ...         ...     ...
# 50222   50223  26.594148   58.861875     1.0
# 50223   50224 -80.385086   78.306156     1.0
# 50232   50233 -82.471792   66.555327     1.0
# 50236   50237  57.536951   79.390440     1.0
# 99999  100000  11.106159   40.230236     1.0
#
# [100000 rows x 4 columns]

# %%
hist = sorted_weight.hist(by=['Weight'],bins=50)
hist
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 hist = sorted_weight.hist(by=['Weight'],bins=50)
#       2 hist
#
# File C:\Developper\Python\Python10.6\lib\site-packages\pandas\plotting\_core.py:232, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     141 """
#     142 Make a histogram of the DataFrame's columns.
#     143
#    (...)
#     229     >>> hist = df.hist(bins=3)
#     230 """
#     231 plot_backend = _get_plot_backend(backend)
# --> 232 return plot_backend.hist_frame(
#     233     data,
#     234     column=column,
#     235     by=by,
#     236     grid=grid,
#     237     xlabelsize=xlabelsize,
#     238     xrot=xrot,
#     239     ylabelsize=ylabelsize,
#     240     yrot=yrot,
#     241     ax=ax,
#     242     sharex=sharex,
#     243     sharey=sharey,
#     244     figsize=figsize,
#     245     layout=layout,
#     246     legend=legend,
#     247     bins=bins,
#     248     **kwargs,
#     249 )
#
# File C:\Developper\Python\Python10.6\lib\site-packages\pandas\plotting\_matplotlib\hist.py:468, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     466     raise ValueError("Cannot use both legend and label")
#     467 if by is not None:
# --> 468     axes = _grouped_hist(
#     469         data,
#     470         column=column,
#     471         by=by,
#     472         ax=ax,
#     473         grid=grid,
#     474         figsize=figsize,
#     475         sharex=sharex,
#     476         sharey=sharey,
#     477         layout=layout,
#     478         bins=bins,
#     479         xlabelsize=xlabelsize,
#     480         xrot=xrot,
#     481         ylabelsize=ylabelsize,
#     482         yrot=yrot,
#     483         legend=legend,
#     484         **kwds,
#     485     )
#     486     return axes
#     488 if column is not None:
#
# File C:\Developper\Python\Python10.6\lib\site-packages\pandas\plotting\_matplotlib\hist.py:352, in _grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, legend, **kwargs)
#     349 if xrot is None:
#     350     xrot = rot
# --> 352 fig, axes = _grouped_plot(
#     353     plot_group,
#     354     data,
#     355     column=column,
#     356     by=by,
#     357     sharex=sharex,
#     358     sharey=sharey,
#     359     ax=ax,
#     360     figsize=figsize,
#     361     layout=layout,
#     362     rot=rot,
#     363 )
#     365 set_ticks_props(
#     366     axes, xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot
#     367 )
#     369 maybe_adjust_figure(
#     370     fig, bottom=0.15, top=0.9, left=0.1, right=0.9, hspace=0.5, wspace=0.3
#     371 )
#
# File C:\Developper\Python\Python10.6\lib\site-packages\pandas\plotting\_matplotlib\hist.py:277, in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#     274     grouped = grouped[column]
#     276 naxes = len(grouped)
# --> 277 fig, axes = create_subplots(
#     278     naxes=naxes, figsize=figsize, sharex=sharex, sharey=sharey, ax=ax, layout=layout
#     279 )
#     281 _axes = flatten_axes(axes)
#     283 for i, (key, group) in enumerate(grouped):
#
# File C:\Developper\Python\Python10.6\lib\site-packages\pandas\plotting\_matplotlib\tools.py:297, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     295         kwds["sharex"] = None
#     296         kwds["sharey"] = None
# --> 297     ax = fig.add_subplot(nrows, ncols, i + 1, **kwds)
#     298     axarr[i] = ax
#     300 if naxes != nplots:
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\figure.py:745, in FigureBase.add_subplot(self, *args, **kwargs)
#     742         args = tuple(map(int, str(args[0])))
#     743     projection_class, pkw = self._process_projection_requirements(
#     744         *args, **kwargs)
# --> 745     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     746     key = (projection_class, pkw)
#     747 return self._add_axes_internal(ax, key)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axes\_subplots.py:34, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      15 """
#      16 Parameters
#      17 ----------
#    (...)
#      31     Keyword arguments are passed to the Axes (sub)class constructor.
#      32 """
#      33 # _axes_class is set in the subplot_class_factory
# ---> 34 self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35 # This will also update the axes position.
#      36 self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axes\_base.py:653, in _AxesBase.__init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     650 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     652 self._rasterization_zorder = None
# --> 653 self.clear()
#     655 # funcs used to format x and y - fall back on major formatters
#     656 self.fmt_xdata = None
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axes\_base.py:1347, in _AxesBase.clear(self)
#    1345     self.cla()
#    1346 else:
# -> 1347     self.__clear()
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axes\_base.py:1275, in _AxesBase.__clear(self)
#    1272 self.legend_ = None
#    1273 self.containers = []
# -> 1275 self.grid(False)  # Disable grid on init to use rcParameter
#    1276 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1277           axis=mpl.rcParams['axes.grid.axis'])
#    1278 props = font_manager.FontProperties(
#    1279     size=mpl.rcParams['axes.titlesize'],
#    1280     weight=mpl.rcParams['axes.titleweight'])
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axes\_base.py:3237, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3235 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3236 if axis in ['x', 'both']:
# -> 3237     self.xaxis.grid(visible, which=which, **kwargs)
#    3238 if axis in ['y', 'both']:
#    3239     self.yaxis.grid(visible, which=which, **kwargs)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:1593, in Axis.grid(self, visible, which, **kwargs)
#    1590 if which in ['major', 'both']:
#    1591     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1592                         if visible is None else visible)
# -> 1593     self.set_tick_params(which='major', **gridkw)
#    1594 self.stale = True
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:940, in Axis.set_tick_params(self, which, reset, **kwargs)
#     938 if which in ['major', 'both']:
#     939     self._major_tick_kw.update(kwtrans)
# --> 940     for tick in self.majorTicks:
#     941         tick._apply_params(**kwtrans)
#     942 if which in ['minor', 'both']:
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:599, in _LazyTickList.__get__(self, instance, cls)
#     597 if self._major:
#     598     instance.majorTicks = []
# --> 599     tick = instance._get_tick(major=True)
#     600     instance.majorTicks.append(tick)
#     601     return instance.majorTicks
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:1483, in Axis._get_tick(self, major)
#    1479     raise NotImplementedError(
#    1480         f"The Axis subclass {self.__class__.__name__} must define "
#    1481         "_tick_class or reimplement _get_tick()")
#    1482 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1483 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:422, in XTick.__init__(self, *args, **kwargs)
#     421 def __init__(self, *args, **kwargs):
# --> 422     super().__init__(*args, **kwargs)
#     423     # x in data coords, y in axes coords
#     424     ax = self.axes
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\axis.py:161, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     154 grid_kw = {k[5:]: v for k, v in kwargs.items()}
#     156 self.tick1line = mlines.Line2D(
#     157     [], [],
#     158     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     159     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     160 )
# --> 161 self.tick2line = mlines.Line2D(
#     162     [], [],
#     163     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     164     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     165 )
#     166 self.gridline = mlines.Line2D(
#     167     [], [],
#     168     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     169     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     170     **grid_kw,
#     171 )
#     172 self.gridline.get_path()._interpolation_steps = \
#     173     GRIDLINE_INTERPOLATION_STEPS
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\lines.py:358, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     355 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#     357 self.set_linewidth(linewidth)
# --> 358 self.set_linestyle(linestyle)
#     359 self.set_drawstyle(drawstyle)
#     361 self._color = None
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\lines.py:1180, in Line2D.set_linestyle(self, ls)
#    1178     self._linestyle = '--'
#    1179 self._unscaled_dash_pattern = _get_dash_pattern(ls)
# -> 1180 self._dash_pattern = _scale_dashes(
#    1181     *self._unscaled_dash_pattern, self._linewidth)
#    1182 self.stale = True
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\lines.py:64, in _scale_dashes(offset, dashes, lw)
#      63 def _scale_dashes(offset, dashes, lw):
# ---> 64     if not mpl.rcParams['lines.scale_dashes']:
#      65         return offset, dashes
#      66     scaled_offset = offset * lw
#
# File C:\Developper\Python\Python10.6\lib\site-packages\matplotlib\__init__.py:658, in RcParams.__getitem__(self, key)
#     653     except KeyError as err:
#     654         raise KeyError(
#     655             f"{key} is not a valid rc parameter (see rcParams.keys() for "
#     656             f"a list of valid parameters)") from err
# --> 658 def __getitem__(self, key):
#     659     if key in _deprecated_map:
#     660         version, alt_key, alt_val, inverse_alt = _deprecated_map[key]
#
# KeyboardInterrupt:
